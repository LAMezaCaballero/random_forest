# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df= pd.read_csv('Feminicidios.csv')
df.head(2)
# Out:
#    Unnamed: 0 name                                         descriptio  \
# 0           0   B2  3-ene. La mujer entre 25 y 30 años fue encontr...
# 1           1   B3  04-ene. La mujer de 29 años que tenia antecede...
#
#        latitud        longitud  \
# 0  258.784.633  -1.002.607.262
# 1  252.606.459  -1.000.087.234
#
#                                           Cosas_Cerc  \
# 0  ['BODEGA AURRERA EXPRESS VALLE DEL NORTE 3159'...
# 1  ['LOTE DE AUTOS EL GALLO', ' AFIRME', ' SIX DE...
#
#                           geometry  TRANSPORTES  TALLER_MECANICO  \
# 0  POINT (-100.2607262 25.8784633)            1                0
# 1  POINT (-100.0087234 25.2606459)            1                0
#
#    CAJEROS_AUTOMATICOS  ...  VPH_CEL  VPH_INTER  VPH_STVP  VPH_SPMVPI  \
# 0                    0  ...     1049        655       421         119
# 1                    0  ...      162         81        94          25
#
#    VPH_CVJ  VPH_SINRTV  VPH_SINLTC  VPH_SINCINT  VPH_SINTIC  #llamadas
# ...

# %%
# info de los datos
df.describe()
# Out:
#        Unnamed: 0  TRANSPORTES  TALLER_MECANICO  CAJEROS_AUTOMATICOS  \
# count  707.000000   707.000000            707.0                707.0
# mean   353.000000     0.050919              0.0                  0.0
# std    204.237607     0.244390              0.0                  0.0
# min      0.000000     0.000000              0.0                  0.0
# 25%    176.500000     0.000000              0.0                  0.0
# 50%    353.000000     0.000000              0.0                  0.0
# 75%    529.500000     0.000000              0.0                  0.0
# max    706.000000     2.000000              0.0                  0.0
#
#              OXXO   ABARROTES  FERRETERIA    DEPOSITO         SIX      TECATE  \
# count  707.000000  707.000000  707.000000  707.000000  707.000000  707.000000
# mean     0.265912    1.292786    0.083451    0.117397    0.257426    0.066478
# std      0.710114    1.825377    0.286812    0.351557    0.695135    0.271068
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707 entries, 0 to 706
# Columns: 257 entries, Unnamed: 0 to #llamadas
# dtypes: float64(2), int64(23), object(232)
# memory usage: 1.4+ MB

# %%
for col in df.columns:
    print(f'Columna: {col}')
    print(f'Tipo de dato: {df[col].dtype}')
    print(f'Valores únicos: {df[col].unique()[:5]}')  # Muestra los primeros 5 valores únicos
    print('-' * 40)
# Out:
# Columna: name
# Tipo de dato: object
# Valores únicos: ['B2' 'B3' 'B37' 'B4' 'B50']
# ----------------------------------------
# Columna: descriptio
# Tipo de dato: object
# Valores únicos: ['3-ene. La mujer entre 25 y 30 años fue encontrada sin vida con huellas de estrangulamiento. #SalinasVictoria. Fuente: El Norte.\xa0https://cutt.ly/DWDim0g'
#  '04-ene. La mujer de 29 años que tenia antecedente de reporte de desaparición, fue encontrada sin vida en una brecha con lesiones por arma blanca. #Allende. Fuente: PuntoxPunto.\xa0https://cutt.ly/kWDiDrJ'
#  '10-jun. La víctima de 25 años fue encontrada en una quinta campestre con herida de arma blanca. #Allende. Fuente: Milenio.\xa0https://cutt.ly/ZWS5zXb'
#  '04-ene. La mujer de entre 35 y 40 años fue encontrada sin vida con huellas de estrangulamiento. #Guadalupe. Fuente: Multimedios.\xa0https://cutt.ly/bWDiVF2'
# ...

# %%
# Verificar si las columnas tienen solo NaN o 0
columnas_vacias_o_cero = df.apply(lambda col: col.isna().all() or (col == 0).all())

# Imprimir las columnas que cumplen la condición
print(columnas_vacias_o_cero[columnas_vacias_o_cero].index.tolist())
# Out:
# ['TALLER_MECANICO', 'CAJEROS_AUTOMATICOS', 'MINI SUPER', 'MZA']

# %%
# limpiar columnas vacias
columnas_a_eliminar = ['TALLER_MECANICO', 'CAJEROS_AUTOMATICOS', 'MINI SUPER', 'MZA']#por ser solo 0 o NaN
df = df.drop(columnas_a_eliminar, axis=1)

# %%
# limpiar columnas innecesarias 
columnas_a_eliminar = ['Unnamed: 0']#, 'name', 'descriptio', 'latitud', 'longitud', 'Cosas_Cerc', 'geometry']
df = df.drop(columnas_a_eliminar, axis=1)
df.tail(5)
# Out:
#     name                                         descriptio      latitud  \
# 702  B77  Fecha: 7/22/2023<br>Hora: Sin dato<br>Nombre d...   25.856.985
# 703  B78  Fecha: 7/26/2023<br>Hora: 7:25<br>Nombre de la...   25.856.985
# 704  B72  Fecha: 6/27/2023<br>Hora: 16:30<br>Nombre de l...   25.772.826
# 705  B75  Fecha: 7/12/2023<br>Hora: Sin dato<br>Nombre d...   25.784.681
# 706  B79  Fecha: 7/27/2023<br>Hora: 20:45<br>Nombre de l...  256.772.312
#
#            longitud                                         Cosas_Cerc  \
# 702    -100.147.159  ['OXXO SUC 50BH2 SAN JORGE MTY', ' BA EXPRESS ...
# 703    -100.147.159  ['OXXO SUC 50BH2 SAN JORGE MTY', ' BA EXPRESS ...
# 704    -100.125.375  ['TRUCAST DE MEXICO', ' WABTEC CORPORATION', '...
# 705    -100.326.865  ['VENTA DE TORTILLAS DE HARINA DOÑA MARY', ' P...
# 706  -1.002.041.179  ['TACOS LA GUERA', ' ABARROTES GOMEZ', ' ESTAN...
#
#                             geometry  TRANSPORTES  OXXO  ABARROTES  \
# ...

# %%
# rellenar con 0 los NaN 
df = df.fillna(0)
df.tail(3)
# Out:
#     name                                         descriptio      latitud  \
# 704  B72  Fecha: 6/27/2023<br>Hora: 16:30<br>Nombre de l...   25.772.826
# 705  B75  Fecha: 7/12/2023<br>Hora: Sin dato<br>Nombre d...   25.784.681
# 706  B79  Fecha: 7/27/2023<br>Hora: 20:45<br>Nombre de l...  256.772.312
#
#            longitud                                         Cosas_Cerc  \
# 704    -100.125.375  ['TRUCAST DE MEXICO', ' WABTEC CORPORATION', '...
# 705    -100.326.865  ['VENTA DE TORTILLAS DE HARINA DOÑA MARY', ' P...
# 706  -1.002.041.179  ['TACOS LA GUERA', ' ABARROTES GOMEZ', ' ESTAN...
#
#                             geometry  TRANSPORTES  OXXO  ABARROTES  \
# 704    POINT (-100.125375 25.772826)            0     0          0
# 705    POINT (-100.326865 25.784681)            0     0          1
# 706  POINT (-100.2041179 25.6772312)            0     0          1
#
#      FERRETERIA  ...  VPH_CEL  VPH_INTER  VPH_STVP  VPH_SPMVPI  VPH_CVJ  \
# ...
